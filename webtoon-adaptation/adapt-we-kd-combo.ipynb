# %%
import pandas as pd 
import numpy as np 
import re

# %%
# Load the adaptation dataset
df_adaptations = pd.read_csv("data/combined/not-clean/combined_adaptations.csv")

# Load the combined kdrama and webtoon datasets
df_kdrama = pd.read_csv("data/combined/not-clean/drama_combined.csv")
df_webtoon = pd.read_csv("data/combined/not-clean/webtoon_combined.csv")

# %%
# Select desired columns from Korean drama and label "Kdrama" in front of each header
kdrama_cols = ['Title', 'Rating', 'Watchers', 'Genres', 'Synopsis', 'Cast', 'Tags']
df_kdrama_selected = df_kdrama[kdrama_cols].copy()
df_kdrama_selected = df_kdrama_selected.rename(columns=lambda x: f"Kdrama {x}" if x!= 'Title' else 'title')

# Select desired columns from webtoon data and label "WE" in front of each header
webtoon_cols = ['Title', 'Rating', 'Subscribers', 'Genre', 'Views', 'Creators']
df_webtoon_selected = df_webtoon[webtoon_cols].copy()
df_webtoon_selected = df_webtoon_selected.rename(columns=lambda x: f"WE {x}" if x != 'Title' else 'title')

# %%
# Merge with drama data
df_adapt_combined = df_adaptations.merge(df_kdrama_selected, on='title', how='left')

# Merge with webtoon data
df_adapt_combined = df_adapt_combined.merge(df_webtoon_selected, on='title', how='left')

# %%
df_adapt_combined
# Out:
#                          title    year  episodes                  0  \
# 0               Chicken Nugget  2024.0      10.0                NaN
# 1               A Superior Day  2022.0       8.0                NaN
# 2       The Forbidden Marriage  2022.0      12.0                NaN
# 3             Gaus Electronics  2022.0      12.0                NaN
# 4      See You in My 19th Life  2023.0      12.0                NaN
# ..                         ...     ...       ...                ...
# 109  Oh Man Sang and Prejudice     NaN       NaN                NaN
# 110            Jinxed at First  2022.0      16.0                NaN
# 111                Bloodhounds  2023.0       8.0                NaN
# 112        A History of Losers  2025.0       8.0                NaN
# 113                        NaN     NaN       NaN  1 Second (manhwa)
#
#      Kdrama Rating Kdrama Watchers                    Kdrama Genres  \
# 0              NaN             NaN                              NaN
# 1              NaN             NaN                              NaN
# 2              NaN             NaN                              NaN
# 3              8.5             NaN  Business, Comedy, Life, Romance
# 4              8.4             NaN  Comedy, Drama, Fantasy, Romance
# ..             ...             ...                              ...
# 109            NaN             NaN                              NaN
# 110            NaN             NaN                              NaN
# 111            NaN             NaN                              NaN
# 112            NaN             NaN                              NaN
# 113            NaN             NaN                              NaN
#
#                                        Kdrama Synopsis  \
# 0                                                  NaN
# 1    Lee Ho Cheol is a regular firefighter. When ne...
# 2    Lee Heon is the king of Joseon. 7 years ago, w...
# 3    Stress is no stranger to the members of Market...
# 4    Ban Ji Eum has an extraordinary ability: she c...
# ..                                                 ...
# 109                                                NaN
# 110  A fishmonger at a traditional market, Gong Soo...
# 111  When reserved rookie boxer Kim Geon Woo square...
# 112                                                NaN
# 113                                                NaN
#
#                                            Kdrama Cast  \
# 0                                                  NaN
# 1    Cho Yu Ha, Ha Do Gwon, Han Yi Jin, Im Hwa Youn...
# 2    Choi Deok Moon, Kim Woo Seok, Kim Young Dae, P...
# 3    Bae Hyun Sung, Baek Hyun Jin, Go Sung Hee, Heo...
# 4    Ahn Bo Hyun, Ahn Dong Goo, Ha Yoon Kyung, Kim ...
# ..                                                 ...
# 109                                                NaN
# 110  Cha Kwang Soo, Jeon Kwang Ryul, Ki Do Hoon, Na...
# 111  Heo Joon Ho, Jung Da Eun, Kim Sae Ron, Lee San...
# 112                                                NaN
# 113                                                NaN
#
#                                            Kdrama Tags  WE Rating  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN       8.76
# 3    Age Gap [Real Life], Heir Male Lead, Hot-tempe...        NaN
# 4    Adapted From A Webtoon, Childhood Friends' Rel...       9.88
# ..                                                 ...        ...
# 109                                                NaN        NaN
# 110                                                NaN        NaN
# 111                                                NaN       9.24
# 112                                                NaN        NaN
# 113                                                NaN        NaN
#
#      WE Subscribers    WE Genre    WE Views            WE Creators
# 0               NaN         NaN         NaN                    NaN
# 1               NaN         NaN         NaN                    NaN
# 2           52038.0  historical    495802.0  Chun Ji hye, Sanchaek
# 3               NaN         NaN         NaN                    NaN
# 4         1423217.0     romance  96091538.0       Lee Hey, Lee Hye
# ..              ...         ...         ...                    ...
# 109             NaN         NaN         NaN                    NaN
# 110             NaN         NaN         NaN                    NaN
# 111        115128.0      action   2301171.0             Jeong Chan
# 112             NaN         NaN         NaN                    NaN
# 113             NaN         NaN         NaN                    NaN
#
# [114 rows x 15 columns]

# %%
required_columns = ['title', 'Kdrama Rating', 'Kdrama Genres', 'Kdrama Synopsis', 'Kdrama Tags']

df_adapt_combined_clean = df_adapt_combined.dropna(subset=required_columns).reset_index(drop=True)
df_adapt_combined_clean = df_adapt_combined_clean[required_columns]

# %%
print('Before:', len(df_adapt_combined))
print('After: ', len(df_adapt_combined_clean))
# Out:
# Before: 114
# After:  28

# %%
df_adapt_combined_clean
# Out:
#                               title  Kdrama Rating  \
# 0                  Gaus Electronics           8.50
# 1           See You in My 19th Life           8.40
# 2                        The 8 Show           7.60
# 3             Divorce Attorney Shin           8.30
# 4                           Save Me           8.60
# 5   What's Wrong with Secretary Kim           8.50
# 6                        Love Alarm           7.10
# 7                      Yumi's Cells           8.50
# 8                              D.P.           8.80
# 9                         Navillera           9.00
# 10                      Taxi Driver           8.80
# 11   At a Distance, Spring Is Green           8.30
# 12             The King's Affection           8.30
# 13                      Light on Me           8.30
# 14            Work Later, Drink Now           8.50
# 15               Our Beloved Summer           8.67
# 16               All of Us Are Dead           8.50
# 17                The Tale of Nokdu           8.40
# 18                    Itaewon Class           8.47
# 19                 Her Private Life           8.37
# 20                Mystic Pop-Up Bar           8.60
# 21                         Memorist           8.40
# 22              The Uncanny Counter           8.80
# 23                           Amanza           8.30
# 24               Seasons of Blossom           8.40
# 25                    Again My Life           8.30
# 26                           Moving           9.10
# 27               The Sound of Magic           8.30
#
#                               Kdrama Genres  \
# 0           Business, Comedy, Life, Romance
# 1           Comedy, Drama, Fantasy, Romance
# 2   Drama, Mystery, Psychological, Thriller
# 3                                Drama, Law
# 4          Action, Drama, Mystery, Thriller
# 5     Business, Comedy, Friendship, Romance
# 6             Comedy, Drama, Romance, Youth
# 7     Comedy, Drama, Psychological, Romance
